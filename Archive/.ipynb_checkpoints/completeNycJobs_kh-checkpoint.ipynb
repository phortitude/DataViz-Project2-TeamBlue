# %% [markdown]
# # Imports

# %%
# import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import os 
import csv 
from sqlalchemy import create_engine

# %%
# File to Load
file_to_load = "Clean_and_complete_NYC_job.csv"

# Read nyc jobs file into Pandas data frame
raw_jobs_data = pd.read_csv(file_to_load)

raw_jobs_data.head()
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0   87990    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  137433   DEPT OF HEALTH/MENTAL HYGIENE     Internal               1
# 3  138531  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 4  152738                  LAW DEPARTMENT     Internal               1
#
#                              Business Title             Civil Service Title  \
# 0                           Account Manager  CONTRACT REVIEWER (OFFICE OF L
# 1  EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT  ADMINISTRATIVE BUSINESS PROMOT
# 2                          Contract Analyst             PROCUREMENT ANALYST
# 3                         Associate Chemist               ASSOCIATE CHEMIST
# 4                            Office Manager              CLERICAL ASSOCIATE
#
#   Title Code No Level                                      Job Category  \
# 0         40563     1                                               NaN
# 1         10009    M3                                               NaN
# 2         12158     3                Finance, Accounting, & Procurement
# 3         21822     2  Health Public Safety, Inspections, & Enforcement
# 4         10251     3                 Clerical & Administrative Support
#
#   Full-Time/Part-Time indicator  ...  \
# 0                           NaN  ...
# 1                             F  ...
# 2                             F  ...
# 3                             F  ...
# 4                             F  ...
#
#                                Residency Requirement             Posting Date  \
# 0  New York City residency is generally required ...  2011-06-24T00:00:00.000
# 1  New York City residency is generally required ...  2012-01-26T00:00:00.000
# 2  New York City residency is generally required ...  2013-12-09T00:00:00.000
# 3  New York City residency is generally required ...  2013-12-20T00:00:00.000
# 4  New York City residency is generally required ...  2014-06-26T00:00:00.000
#
#   Post Until          Posting Updated             Process Date    New Lat  \
# 0        NaN  2011-06-24T00:00:00.000  2019-07-30T00:00:00.000  40.708793
# 1        NaN  2012-01-26T00:00:00.000  2019-07-30T00:00:00.000  40.708793
# 2        NaN  2013-12-09T00:00:00.000  2019-07-30T00:00:00.000  40.749357
# 3        NaN  2014-07-25T00:00:00.000  2019-07-30T00:00:00.000  40.734880
# 4        NaN  2014-06-26T00:00:00.000  2019-07-30T00:00:00.000  40.713299
#
#     New Long                                  Formatted Address      Zip  \
# 0 -74.006836            110 William St, New York, NY 10038, USA  10038.0
# 1 -74.006836            110 William St, New York, NY 10038, USA  10038.0
# 2 -73.939062     42-09 28th St, Long Island City, NY 11101, USA  11101.0
# 3 -73.863489  96-05 Horace Harding Expy, Elmhurst, NY 11373,...  11373.0
# 4 -74.010110             100 Church St, New York, NY 10007, USA  10007.0
#
#      Borough
# 0  Manhattan
# 1  Manhattan
# 2     Queens
# 3     Queens
# 4  Manhattan
#
# [5 rows x 33 columns]

# %%
raw_jobs_data.columns
# Out:
# Index(['Job ID', 'Agency', 'Posting Type', '# Of Positions', 'Business Title',
#        'Civil Service Title', 'Title Code No', 'Level', 'Job Category',
#        'Full-Time/Part-Time indicator', 'Salary Range From', 'Salary Range To',
#        'Salary Frequency', 'Work Location', 'Division/Work Unit',
#        'Job Description', 'Minimum Qual Requirements', 'Preferred Skills',
#        'Additional Information', 'To Apply', 'Hours/Shift', 'Work Location 1',
#        'Recruitment Contact', 'Residency Requirement', 'Posting Date',
#        'Post Until', 'Posting Updated', 'Process Date', 'New Lat', 'New Long',
#        'Formatted Address', 'Zip', 'Borough'],
#       dtype='object')

# %%
# rename column headers
# jobs_df.columns = ['jobID', 'agency', 'businessTitle', '#ofPositions', 'jobCategory', 'salaryRangeFrom', 'salaryRangeTo', 'workLocation1']
#jobs_df = jobs_df.rename(columns={'Job ID': 'jobID', 'Agency': 'agency', 'Posting Type': 'postingType', '# Of Positions':'numOfPositions','Business Title': 'businessTitle',  'Civil Service Title': 'civilServiceTitle',\
                                  #'Title Code No': 'titleCodeNo', 'Level': 'level', 'Job Category': 'jobCategory', 'Full-Time/Part-Time indicator': 'fullTimePartTime', 'Salary Range From': 'salaryRangeFrom', 'Salary Range To': 'salaryRangeTo', 'Salary Frequency': 'salaryFrequency', '''Residency Requirement': 'residenceRequirement', 'Posting Date': 'postingDate',\
                                  #'Title Code No': 'titleCodeNo', 'Level': 'level', 'Job Category': 'jobCategory', 'Full-Time/Part-Time indicator': 'fullTimePartTime', 'Salary Range From': 'salaryRangeFrom', 'Salary Range To': 'salaryRangeTo', 'Salary Frequency': 'salaryFrequency', '''Residency Requirement': 'residenceRequirement', 'Posting Date': 'postingDate',\
                                  #'Post Until': 'postUntil', 'Posting Updated': 'postingUpdated', 'Process Date': 'processDate', 'New Lat': 'newLat', 'New Long': 'newLong', 'Formatted Address': 'formattedAddress', 'Zip':'zip', 'Borough': 'borough', 'Work Location 1': 'workLocation1'})

raw_jobs_df = raw_jobs_data.rename(columns={'Job ID':'jobID', 'Agency':'agency', 'Posting Type':'postingType', '# Of Positions':'numOfPositions', 'Business Title':'businessTitle',\
       'Civil Service Title':'civilServiceTitle', 'Title Code No':'titleCodeNo', 'Level':'level', 'Job Category':'jobCategory',\
       'Full-Time/Part-Time indicator':'fullTimePartTime', 'Salary Range From':'salaryRangeFrom', 'Salary Range To':'salaryRangeTo',\
       'Salary Frequency':'salaryFrequency', 'Work Location':'workLocation', 'Division/Work Unit':'divisionWorkUnit',\
       'Job Description':'jobDescripton', 'Minimum Qual Requirements':'minQualRequirements', 'Preferred Skills':'preferredSkills',\
       'Additional Information':'additionalInformation', 'To Apply':'toApply', 'Hours/Shift':'hoursShift', 'Work Location 1':'workLocation1',\
       'Recruitment Contact':'recruitmentContact', 'Residency Requirement':'residencyRequirement', 'Posting Date':'postingDate',\
       'Post Until':'postUntil', 'Posting Updated':'postingUpdated', 'Process Date':'processDate', 'New Lat':'newLat', 'New Long':'newLong',\
       'Formatted Address':'formattedAddress', 'Zip':'zip', 'Borough':'borough' })

 # name the index column
raw_jobs_df.index.name = 'index'
raw_jobs_df.head()
# Out:
#         jobID                          agency postingType  numOfPositions  \
# index
# 0       87990    DEPARTMENT OF BUSINESS SERV.    Internal               1
# 1       97899    DEPARTMENT OF BUSINESS SERV.    Internal               1
# 2      137433   DEPT OF HEALTH/MENTAL HYGIENE    Internal               1
# 3      138531  DEPT OF ENVIRONMENT PROTECTION    Internal               1
# 4      152738                  LAW DEPARTMENT    Internal               1
#
#                                   businessTitle  \
# index
# 0                               Account Manager
# 1      EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2                              Contract Analyst
# 3                             Associate Chemist
# 4                                Office Manager
#
#                     civilServiceTitle titleCodeNo level  \
# index
# 0      CONTRACT REVIEWER (OFFICE OF L       40563     1
# 1      ADMINISTRATIVE BUSINESS PROMOT       10009    M3
# 2                 PROCUREMENT ANALYST       12158     3
# 3                   ASSOCIATE CHEMIST       21822     2
# 4                  CLERICAL ASSOCIATE       10251     3
#
#                                             jobCategory fullTimePartTime  ...  \
# index                                                                     ...
# 0                                                   NaN              NaN  ...
# 1                                                   NaN                F  ...
# 2                    Finance, Accounting, & Procurement                F  ...
# 3      Health Public Safety, Inspections, & Enforcement                F  ...
# 4                     Clerical & Administrative Support                F  ...
#
#                                     residencyRequirement  \
# index
# 0      New York City residency is generally required ...
# 1      New York City residency is generally required ...
# 2      New York City residency is generally required ...
# 3      New York City residency is generally required ...
# 4      New York City residency is generally required ...
#
#                    postingDate postUntil           postingUpdated  \
# index
# 0      2011-06-24T00:00:00.000       NaN  2011-06-24T00:00:00.000
# 1      2012-01-26T00:00:00.000       NaN  2012-01-26T00:00:00.000
# 2      2013-12-09T00:00:00.000       NaN  2013-12-09T00:00:00.000
# 3      2013-12-20T00:00:00.000       NaN  2014-07-25T00:00:00.000
# 4      2014-06-26T00:00:00.000       NaN  2014-06-26T00:00:00.000
#
#                    processDate     newLat    newLong  \
# index
# 0      2019-07-30T00:00:00.000  40.708793 -74.006836
# 1      2019-07-30T00:00:00.000  40.708793 -74.006836
# 2      2019-07-30T00:00:00.000  40.749357 -73.939062
# 3      2019-07-30T00:00:00.000  40.734880 -73.863489
# 4      2019-07-30T00:00:00.000  40.713299 -74.010110
#
#                                         formattedAddress      zip    borough
# index
# 0                110 William St, New York, NY 10038, USA  10038.0  Manhattan
# 1                110 William St, New York, NY 10038, USA  10038.0  Manhattan
# 2         42-09 28th St, Long Island City, NY 11101, USA  11101.0     Queens
# 3      96-05 Horace Harding Expy, Elmhurst, NY 11373,...  11373.0     Queens
# 4                 100 Church St, New York, NY 10007, USA  10007.0  Manhattan
#
# [5 rows x 33 columns]

# %%
# find unique job categories

raw_jobs_df.jobCategory.unique()

# %%
raw_jobs_df.dtypes
# Out:
# jobID                      int64
# agency                    object
# postingType               object
# numOfPositions             int64
# businessTitle             object
# civilServiceTitle         object
# titleCodeNo               object
# level                     object
# jobCategory               object
# fullTimePartTime          object
# salaryRangeFrom          float64
# salaryRangeTo            float64
# salaryFrequency           object
# workLocation              object
# divisionWorkUnit          object
# jobDescripton             object
# minQualRequirements       object
# preferredSkills           object
# additionalInformation     object
# toApply                   object
# hoursShift                object
# workLocation1             object
# recruitmentContact       float64
# residencyRequirement      object
# postingDate               object
# postUntil                 object
# postingUpdated            object
# processDate               object
# newLat                   float64
# newLong                  float64
# formattedAddress          object
# zip                      float64
# borough                   object
# dtype: object

# %%
# save to output file
raw_jobs_df.to_csv("completeAndCleanNycJobs_kh.csv")
