# %%
import pandas as pd

# %%
data = "nycdata.csv"

# %%
nydata = pd.read_csv(data)
nydata.head()
# Out:
#    Job ID                        Agency Posting Type  # Of Positions  \
# 0   87990  DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899  DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  132292         NYC HOUSING AUTHORITY     External              52
# 3  132292         NYC HOUSING AUTHORITY     Internal              52
# 4  133921         NYC HOUSING AUTHORITY     Internal              50
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title Title Code No Level  \
# 0  CONTRACT REVIEWER (OFFICE OF L         40563     1
# 1  ADMINISTRATIVE BUSINESS PROMOT         10009    M3
# 2              MAINTENANCE WORKER         90698     0
# ...

# %%
nydata.columns
# Out:
# Index(['Job ID', 'Agency', 'Posting Type', '# Of Positions', 'Business Title',
#        'Civil Service Title', 'Title Code No', 'Level', 'Job Category',
#        'Full-Time/Part-Time indicator', 'Salary Range From', 'Salary Range To',
#        'Salary Frequency', 'Work Location', 'Division/Work Unit',
#        'Job Description', 'Minimum Qual Requirements', 'Preferred Skills',
#        'Additional Information', 'To Apply', 'Hours/Shift', 'Work Location 1',
#        'Recruitment Contact', 'Residency Requirement', 'Posting Date',
#        'Post Until', 'Posting Updated', 'Process Date', 'New Lat', 'New Long',
#        'Formatted Address', 'Zip'],
#       dtype='object')

# %%
nydata_df = nydata.loc[:, ["Agency", 'Job Category', "Business Title",
                                    "Civil Service Title", "Salary Range From", "Salary Range To", "New Lat", "New Long", 'Zip']]
nydata_df.head()
# Out:
#                          Agency              Job Category  \
# 0  DEPARTMENT OF BUSINESS SERV.                       NaN
# 1  DEPARTMENT OF BUSINESS SERV.                       NaN
# 2         NYC HOUSING AUTHORITY  Maintenance & Operations
# 3         NYC HOUSING AUTHORITY  Maintenance & Operations
# 4         NYC HOUSING AUTHORITY  Maintenance & Operations
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title  Salary Range From  Salary Range To  \
# 0  CONTRACT REVIEWER (OFFICE OF L           42405.00         65485.00
# 1  ADMINISTRATIVE BUSINESS PROMOT           60740.00        162014.00
# 2              MAINTENANCE WORKER           51907.68         54580.32
# ...

# %%
nydata_df.count()
# Out:
# Agency                 3123
# Job Category           3121
# Business Title         3123
# Civil Service Title    3123
# Salary Range From      3123
# Salary Range To        3123
# New Lat                2995
# New Long               2995
# Zip                    2972
# dtype: int64

# %%
nydata_final = nydata_df.dropna()
nydata_final.count()
# Out:
# Agency                 2970
# Job Category           2970
# Business Title         2970
# Civil Service Title    2970
# Salary Range From      2970
# Salary Range To        2970
# New Lat                2970
# New Long               2970
# Zip                    2970
# dtype: int64

# %%
nydata_final['Job Category'].unique()
# Out:
# array(['Finance, Accounting, & Procurement',
#        'Health Public Safety, Inspections, & Enforcement',
#        'Clerical & Administrative Support',
#        'Information Technology & Telecommunications',
#        'Finance, Accounting, & Procurement Information Technology & Telecommunications',
#        'Community & Business Services',
#        'Clerical & Administrative Support Legal',
#        'Clerical & Administrative Support Community & Business Services',
#        'Social Services',
#        'Engineering, Architecture, & Planning Maintenance & Operations',
#        'Health', 'Maintenance & Operations',
#        'Clerical & Administrative Support Policy & Analysis',
#        'Community & Business Services Social Services',
#        'Public Safety, Inspections, & Enforcement',
#        'Policy & Analysis Social Services',
#        'Information Technology & Telecommunications Policy & Analysis Social Services',
# ...
