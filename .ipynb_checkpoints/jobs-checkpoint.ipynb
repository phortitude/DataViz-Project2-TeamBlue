# %% [markdown]
# # IMPORTS

# %%
# import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import os 
import csv 
from sqlalchemy import create_engine

# %% [markdown]
# # IMPORT DATA SOURCES

# %%
# File to Load
file_to_load = "nyc-jobs.csv"

# Read nyc jobs file into Pandas data frame
raw_jobs_data = pd.read_csv(file_to_load)

raw_jobs_data.head()
# Out:
#    Job ID                        Agency Posting Type  # Of Positions  \
# 0   87990  DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899  DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  132292         NYC HOUSING AUTHORITY     External              52
# 3  132292         NYC HOUSING AUTHORITY     Internal              52
# 4  133921         NYC HOUSING AUTHORITY     Internal              50
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title Title Code No Level  \
# 0  CONTRACT REVIEWER (OFFICE OF L         40563     1
# 1  ADMINISTRATIVE BUSINESS PROMOT         10009    M3
# 2              MAINTENANCE WORKER         90698     0
# ...

# %% [markdown]
# # CREATE DATA FRAME WITH SELECTED VARIABLES

# %%
# Select Job ID, Agency, Business Title, # Of Positions, Business Title,Job Category, Salary Range From, Salary Range To, 
# Work Location, Work Location 1

raw_jobs_df = pd.DataFrame(jobs_data)

# %%
raw_jobs_df.head()
# Out:
#    Job ID                        Agency Posting Type  # Of Positions  \
# 0   87990  DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899  DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  132292         NYC HOUSING AUTHORITY     External              52
# 3  132292         NYC HOUSING AUTHORITY     Internal              52
# 4  133921         NYC HOUSING AUTHORITY     Internal              50
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title Title Code No Level  \
# 0  CONTRACT REVIEWER (OFFICE OF L         40563     1
# 1  ADMINISTRATIVE BUSINESS PROMOT         10009    M3
# 2              MAINTENANCE WORKER         90698     0
# ...

# %%
# jobs_df['Job Category'].value_counts()
# len(jobs_df) - jobs_df['Job Category'].count()
# jobs = raw_jobs_df.dropna()

new_jobs_df = raw_jobs_df[["Job ID", "Agency", "Business Title", "# Of Positions", "Business Title","Job Category", "Salary Range From", "Salary Range To","Work Location"]] 
new_jobs_df.head()
# Out:
#    Job ID                        Agency  \
# 0   87990  DEPARTMENT OF BUSINESS SERV.
# 1   97899  DEPARTMENT OF BUSINESS SERV.
# 2  132292         NYC HOUSING AUTHORITY
# 3  132292         NYC HOUSING AUTHORITY
# 4  133921         NYC HOUSING AUTHORITY
#
#                                       Business Title  # Of Positions  \
# 0                                    Account Manager               1
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT               1
# 2  Maintenance Worker - Technical Services-Heatin...              52
# 3  Maintenance Worker - Technical Services-Heatin...              52
# 4                                  Temporary Painter              50
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# ...

# %%
jobs_nan = new_jobs_df[new_jobs_df["Job Category"].isnull()]
jobs_nan
# Out:
#    Job ID                        Agency  \
# 0   87990  DEPARTMENT OF BUSINESS SERV.
# 1   97899  DEPARTMENT OF BUSINESS SERV.
#
#                              Business Title  # Of Positions  \
# 0                           Account Manager               1
# 1  EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT               1
#
#                              Business Title Job Category  Salary Range From  \
# 0                           Account Manager          NaN            42405.0
# 1  EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT          NaN            60740.0
#
#    Salary Range To        Work Location
# 0          65485.0  110 William St. N Y
# 1         162014.0  110 William St. N Y
